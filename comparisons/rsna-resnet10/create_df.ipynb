# %%
import pandas as pd

# %%
train_df = pd.read_csv("/home/rfyahya/Desktop/Rawan/brain/clean/visual studios/dataframes/training_set_t2w.csv")
val_df = pd.read_csv("/home/rfyahya/Desktop/Rawan/brain/clean/visual studios/dataframes/validation_set_t2w.csv")
train_df = pd.read_csv("/home/rfyahya/Desktop/Rawan/brain/clean/visual studios/dataframes/training_set_t2w.csv")
test_df = pd.read_csv("/home/rfyahya/Desktop/Rawan/brain/clean/visual studios/dataframes/testing_set_t2w.csv")

# %%
val_df
# Out:
#     Unnamed: 0  Unnamed: 0.1  BraTS21ID  MGMT_value  \
# 0         1677          1677       1009           0
# 1         1583          1583        816           1
# 2          919           919        570           1
# 3         1419          1419        758           1
# 4         1635          1635        840           1
# 5          805           805        533           0
# 6         1909           225        111           0
# 7         1294          1294        707           1
# 8         1675          1675       1008           1
# 9          319           319        348           0
# 10        1637          1637        998           1
# 11         671           671        485           1
# 12         987           987        590           1
# 13        1227          1227        683           0
# 14        1466          1466        778           0
# 15           3             3         28           1
# 16        1939           255        128           1
# ...
